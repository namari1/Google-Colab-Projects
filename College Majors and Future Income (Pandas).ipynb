# %%
import pandas as pd
df = pd.read_csv('salaries_by_college_major.csv')

# %%
df.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %%
df.shape
# Out:
# (51, 6)

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
df.isna()
# Out:
#     Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0                 False                   False                     False
# 1                 False                   False                     False
# 2                 False                   False                     False
# 3                 False                   False                     False
# 4                 False                   False                     False
# 5                 False                   False                     False
# 6                 False                   False                     False
# 7                 False                   False                     False
# 8                 False                   False                     False
# 9                 False                   False                     False
# 10                False                   False                     False
# 11                False                   False                     False
# ...

# %%
df.tail()
# Out:
#       Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 46             Psychology                 35900.0                   60400.0
# 47               Religion                 34100.0                   52000.0
# 48              Sociology                 36500.0                   58200.0
# 49                Spanish                 34000.0                   53100.0
# 50  Source: PayScale Inc.                     NaN                       NaN
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS
# 50                                NaN                                NaN   NaN

# %%
clean_df = df.dropna()

# %%
clean_df.tail()
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 45   Political Science                 40800.0                   78200.0
# 46          Psychology                 35900.0                   60400.0
# 47            Religion                 34100.0                   52000.0
# 48           Sociology                 36500.0                   58200.0
# 49             Spanish                 34000.0                   53100.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 45                            41200.0                           168000.0  HASS
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS

# %%
clean_df["Starting Median Salary"].max()
# Out:
# 74300.0

# %%
clean_df["Starting Median Salary"].idxmax()
# Out:
# 43

# %%
clean_df["Undergraduate Major"].loc[43]
# Out:
# 'Physician Assistant'

# %%
clean_df["Undergraduate Major"][43]
# Out:
# 'Physician Assistant'

# %%
clean_df.loc[43]
# Out:
# Undergraduate Major                  Physician Assistant
# Starting Median Salary                           74300.0
# Mid-Career Median Salary                         91700.0
# Mid-Career 10th Percentile Salary                66400.0
# Mid-Career 90th Percentile Salary               124000.0
# Group                                               STEM
# Name: 43, dtype: object

# %%
clean_df["Mid-Career Median Salary"].idxmax()
# Out:
# 8

# %%
clean_df["Undergraduate Major"][8]
# Out:
# 'Chemical Engineering'

# %%
clean_df.loc[8]
# Out:
# Undergraduate Major                  Chemical Engineering
# Starting Median Salary                            63200.0
# Mid-Career Median Salary                         107000.0
# Mid-Career 10th Percentile Salary                 71900.0
# Mid-Career 90th Percentile Salary                194000.0
# Group                                                STEM
# Name: 8, dtype: object

# %%
clean_df["Starting Median Salary"].idxmin()
# Out:
# 49

# %%
clean_df.loc[49]
# Out:
# Undergraduate Major                  Spanish
# Starting Median Salary               34000.0
# Mid-Career Median Salary             53100.0
# Mid-Career 10th Percentile Salary    31000.0
# Mid-Career 90th Percentile Salary    96400.0
# Group                                   HASS
# Name: 49, dtype: object

# %%
clean_df["Mid-Career Median Salary"].idxmin()
# Out:
# 18

# %%
clean_df.loc[18]
# Out:
# Undergraduate Major                  Education
# Starting Median Salary                 34900.0
# Mid-Career Median Salary               52000.0
# Mid-Career 10th Percentile Salary      29300.0
# Mid-Career 90th Percentile Salary     102000.0
# Group                                     HASS
# Name: 18, dtype: object

# %%
percentile_diff = clean_df['Mid-Career 90th Percentile Salary'].subtract(clean_df['Mid-Career 10th Percentile Salary'])

# %%
clean_df.insert(1, "90-10 Percentile Spread", percentile_diff)

# %%
clean_df.head()
# Out:
#      Undergraduate Major  90-10 Percentile Spread  Starting Median Salary  \
# 0             Accounting                 109800.0                 46000.0
# 1  Aerospace Engineering                  96700.0                 57700.0
# 2            Agriculture                 113700.0                 42600.0
# 3           Anthropology                 104200.0                 36800.0
# 4           Architecture                  85400.0                 41600.0
#
#    Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 0                   77100.0                            42200.0
# 1                  101000.0                            64300.0
# 2                   71900.0                            36300.0
# 3                   61500.0                            33800.0
# 4                   76800.0                            50600.0
#
#    Mid-Career 90th Percentile Salary     Group
# 0                           152000.0  Business
# ...

# %%
low_risk = clean_df.sort_values("90-10 Percentile Spread")

# %%
low_risk[["Undergraduate Major", "90-10 Percentile Spread"]].head()
# Out:
#            Undergraduate Major  90-10 Percentile Spread
# 40                     Nursing                  50700.0
# 43         Physician Assistant                  57600.0
# 41                   Nutrition                  65300.0
# 49                     Spanish                  65400.0
# 27  Health Care Administration                  66400.0

# %%
high_pot = clean_df.sort_values("Mid-Career 90th Percentile Salary", ascending=False)

# %%
high_pot.head()
# Out:
#      Undergraduate Major  90-10 Percentile Spread  Starting Median Salary  \
# 17             Economics                 159400.0                 50100.0
# 22               Finance                 147800.0                 47900.0
# 8   Chemical Engineering                 122100.0                 63200.0
# 37                  Math                 137800.0                 45400.0
# 44               Physics                 122000.0                 50300.0
#
#     Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 17                   98600.0                            50600.0
# 22                   88300.0                            47200.0
# 8                   107000.0                            71900.0
# 37                   92400.0                            45200.0
# 44                   97300.0                            56000.0
#
#     Mid-Career 90th Percentile Salary     Group
# 17                           210000.0  Business
# ...

# %%
high_risk = clean_df.sort_values("90-10 Percentile Spread", ascending=False)

# %%
high_risk.head()
# Out:
#    Undergraduate Major  90-10 Percentile Spread  Starting Median Salary  \
# 17           Economics                 159400.0                 50100.0
# 22             Finance                 147800.0                 47900.0
# 37                Math                 137800.0                 45400.0
# 36           Marketing                 132900.0                 40800.0
# 42          Philosophy                 132500.0                 39900.0
#
#     Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 17                   98600.0                            50600.0
# 22                   88300.0                            47200.0
# 37                   92400.0                            45200.0
# 36                   79600.0                            42100.0
# 42                   81200.0                            35500.0
#
#     Mid-Career 90th Percentile Salary     Group
# 17                           210000.0  Business
# 22                           195000.0  Business
# ...

# %%
top_median = clean_df.sort_values("Starting Median Salary", ascending=False)

# %%
top_median.head()
# Out:
#        Undergraduate Major  90-10 Percentile Spread  Starting Median Salary  \
# 43     Physician Assistant                  57600.0                 74300.0
# 8     Chemical Engineering                 122100.0                 63200.0
# 12    Computer Engineering                  95900.0                 61400.0
# 19  Electrical Engineering                  98700.0                 60900.0
# 38  Mechanical Engineering                  99300.0                 57900.0
#
#     Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 43                   91700.0                            66400.0
# 8                   107000.0                            71900.0
# 12                  105000.0                            66100.0
# 19                  103000.0                            69300.0
# 38                   93600.0                            63700.0
#
#     Mid-Career 90th Percentile Salary Group
# 43                           124000.0  STEM
# ...

# %%
clean_df.groupby("Group").count()
# Out:
#           Undergraduate Major  90-10 Percentile Spread  \
# Group
# Business                   12                       12
# HASS                       22                       22
# STEM                       16                       16
#
#           Starting Median Salary  Mid-Career Median Salary  \
# Group
# Business                      12                        12
# HASS                          22                        22
# STEM                          16                        16
#
#           Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# Group
# Business                                 12                                 12
# HASS                                     22                                 22
# STEM                                     16                                 16

# %%
clean_df.groupby("Group").mean()
# Out:
# <ipython-input-41-efdc932833d8>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   clean_df.groupby("Group").mean()
#           90-10 Percentile Spread  Starting Median Salary  \
# Group
# Business            103958.333333            44633.333333
# HASS                 95218.181818            37186.363636
# STEM                101600.000000            53862.500000
#
#           Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# Group
# Business              75083.333333                       43566.666667
# HASS                  62968.181818                       34145.454545
# STEM                  90812.500000                       56025.000000
#
#           Mid-Career 90th Percentile Salary
# Group
# Business                      147525.000000
# ...

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
clean_df.groupby("Group").mean()
# Out:
# <ipython-input-43-efdc932833d8>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   clean_df.groupby("Group").mean()
#           90-10 Percentile Spread  Starting Median Salary  \
# Group
# Business               103,958.33               44,633.33
# HASS                    95,218.18               37,186.36
# STEM                   101,600.00               53,862.50
#
#           Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# Group
# Business                 75,083.33                          43,566.67
# HASS                     62,968.18                          34,145.45
# STEM                     90,812.50                          56,025.00
#
#           Mid-Career 90th Percentile Salary
# Group
# Business                         147,525.00
# ...

# %% [markdown]
# # New Section
